# %% [markdown]
# # PokerBotRL Code Walkthrough

# %% [markdown]
# ## Prerequisites
#
# This notebook assumes:
# 1.  You have a Python environment with necessary libraries installed (torch, numpy, gymnasium).
# 2.  You are running this notebook server from the root `PokerBotRL` directory.
# 4.  For `simulate`, `analyze`, and `ui` commands, a trained model checkpoint may be required in the `checkpoints/` folder.
# 5.  For the `analyze` command, a `detailed_simulation_log.csv` file generated by `simulate` needs to exist.

# %% [markdown]
# ## File Descriptions
#
# * **`main.py`**: The main entry point for the project. Uses `argparse` to handle command-line arguments and dispatch tasks like training, simulation, analysis, or running the UI.
# * **`envs.py`**: Defines the Gymnasium-compliant poker environment (`BaseFullPokerEnv`, `TrainFullPokerEnv`).
# * **`models.py`**: Contains the PyTorch neural network architecture (`BestPokerModel`).
# * **`utils.py`**: Provides utility functions including state encoding, replay buffer, epsilon decay, and model loading helpers.
# * **`card_utils.py`**: Card parsing and rendering (including ASCII art).
# * **`seat_config.py`**: Manages seat configuration (e.g., AI, human, random).
# * **`train.py`**: Implements the RL training loop.
# * **`simulate.py`**: Runs simulation episodes using a trained model.
# * **`main_ui.py`**: Launches a Tkinter-based GUI for human interaction.
# * **`decision_analysis.py`**: Evaluates decisions from simulation logs.
# * **`human_action_handler.py`**: Likely used to interpret human-like actions or strategies.
# * **`plot.py`**: Plots rewards and metrics from logs.
# * **`readme.txt`**: Project usage and overview.
# * **`code_walkthrough.ipynb`**: This notebook.

# %% [markdown]
# ## Command-Line Usage (`main.py`)
# The `main.py` script serves as the central command-line interface.

# %%
# !python main.py --help
# !python main.py train --help

# %% [markdown]
# ### 1. Train Command
# **Purpose:** Train the RL agent model.
#
# 31380

# %%
# !python main.py train --episodes 50000 --resume "checkpoints/checkpoint_30500.pt"
# Out:
# ^C

# %%
# !python main.py train --episodes 2000

# %%
# !python main.py train --episodes 500000 --resume "checkpoints/checkpoint_100.pt"  --random 5000-10000 --variable

# %% [markdown]
# ### 2. Simulate Command
# **Purpose:** Run simulations using a trained agent checkpoint.

# %%
# !python main.py simulate --checkpoint "checkpoints/checkpoint_31200.pt" --episodes 500 --opponent "random"
# Out:
# Starting simulation process...
# Closing Poker Environment.
# Dynamically obtained Action List: ['fold', 'call', 'check', 'bet_small', 'bet_big', 'all_in']
# Using device: cpu
# Loading checkpoint from checkpoints/checkpoint_31200.pt
# Successfully loaded model from checkpoints/checkpoint_31200.pt onto cpu.
# Seat configuration: {0: 'agent', 1: 'random', 2: 'random', 3: 'random', 4: 'random', 5: 'random'}
# Set Seat 2 policy to: random
# Set Seat 3 policy to: random
# Set Seat 4 policy to: random
# Set Seat 5 policy to: random
# Set Seat 6 policy to: random
# Overwriting detailed log file: detailed_simulation_log.csv
#
# --- Starting Simulation (500 tournaments) ---
# --- Starting Simulation Tournament 1 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 1. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 2 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 2. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 3 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 3. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 4 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 4. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 5 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 5. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 6 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 6. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 7 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# --- Finished Simulation Tournament 7. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 8 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# --- Finished Simulation Tournament 8. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 9 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 9. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 10 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 10. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 11 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 11. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 12 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 12. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 13 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# --- Finished Simulation Tournament 13. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 14 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 14. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 15 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 15. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 16 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 16. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 17 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 17. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 18 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 18. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 19 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 19. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 20 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 20. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 21 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 21. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 22 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 22. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 23 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 23. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 24 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing river...
# --- Finished Simulation Tournament 24. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 25 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# --- Finished Simulation Tournament 25. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 26 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 26. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 27 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing river...
# --- All-in Runout Detected ---
# Dealing river...
# --- Finished Simulation Tournament 27. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 28 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 28. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 29 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 29. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 30 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 30. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 31 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 31. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 32 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 32. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 33 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 33. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 34 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 34. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 35 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 35. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 36 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 36. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 37 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 37. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 38 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 38. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 39 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 39. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 40 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 40. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 41 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing river...
# --- Finished Simulation Tournament 41. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 42 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# --- Finished Simulation Tournament 42. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 43 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 43. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 44 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 44. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 45 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 45. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 46 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 46. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 47 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 47. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 48 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 48. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 49 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 49. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 50 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 50. Final Reward: -10000.00 ---
#   Completed Tournament 50/500...
# --- Starting Simulation Tournament 51 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 51. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 52 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 52. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 53 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 53. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 54 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 54. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 55 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 55. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 56 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 56. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 57 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing river...
# --- All-in Runout Detected ---
# --- All-in Runout Detected ---
# Dealing river...
# --- Finished Simulation Tournament 57. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 58 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 58. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 59 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 59. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 60 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 60. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 61 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 61. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 62 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 62. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 63 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 63. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 64 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 64. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 65 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 65. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 66 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 66. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 67 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 67. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 68 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 68. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 69 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# --- Finished Simulation Tournament 69. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 70 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing river...
# --- Finished Simulation Tournament 70. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 71 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 71. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 72 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 72. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 73 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 73. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 74 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 74. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 75 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 75. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 76 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 76. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 77 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 77. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 78 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing river...
# --- Finished Simulation Tournament 78. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 79 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 79. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 80 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 80. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 81 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 81. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 82 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 82. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 83 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 83. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 84 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 84. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 85 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 85. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 86 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 86. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 87 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 87. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 88 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 88. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 89 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 89. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 90 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 90. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 91 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 91. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 92 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 92. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 93 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 93. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 94 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 94. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 95 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 95. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 96 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 96. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 97 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 97. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 98 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 98. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 99 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 99. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 100 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 100. Final Reward: -10000.00 ---
#   Completed Tournament 100/500...
# --- Starting Simulation Tournament 101 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 101. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 102 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing river...
# --- Finished Simulation Tournament 102. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 103 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 103. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 104 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 104. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 105 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 105. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 106 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# --- Finished Simulation Tournament 106. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 107 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 107. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 108 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 108. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 109 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 109. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 110 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing river...
# --- Finished Simulation Tournament 110. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 111 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 111. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 112 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 112. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 113 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# --- Finished Simulation Tournament 113. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 114 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# --- Finished Simulation Tournament 114. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 115 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing river...
# --- Finished Simulation Tournament 115. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 116 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 116. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 117 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 117. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 118 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 118. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 119 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 119. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 120 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 120. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 121 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 121. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 122 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 122. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 123 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 123. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 124 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 124. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 125 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 125. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 126 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 126. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 127 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 127. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 128 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 128. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 129 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 129. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 130 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 130. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 131 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 131. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 132 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 132. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 133 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# --- All-in Runout Detected ---
# Dealing river...
# --- Finished Simulation Tournament 133. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 134 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 134. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 135 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 135. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 136 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 136. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 137 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 137. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 138 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 138. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 139 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 139. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 140 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 140. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 141 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 141. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 142 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing river...
# --- Finished Simulation Tournament 142. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 143 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# --- Finished Simulation Tournament 143. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 144 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 144. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 145 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 145. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 146 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 146. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 147 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 147. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 148 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 148. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 149 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing river...
# --- Finished Simulation Tournament 149. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 150 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 150. Final Reward: -10000.00 ---
#   Completed Tournament 150/500...
# --- Starting Simulation Tournament 151 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 151. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 152 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 152. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 153 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 153. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 154 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 154. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 155 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 155. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 156 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 156. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 157 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 157. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 158 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 158. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 159 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# ...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 447. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 448 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 448. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 449 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 449. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 450 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 450. Final Reward: -10000.00 ---
#   Completed Tournament 450/500...
# --- Starting Simulation Tournament 451 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing river...
# --- Finished Simulation Tournament 451. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 452 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 452. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 453 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 453. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 454 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 454. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 455 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 455. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 456 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing river...
# --- Finished Simulation Tournament 456. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 457 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 457. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 458 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 458. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 459 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# --- Finished Simulation Tournament 459. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 460 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 460. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 461 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing river...
# --- Finished Simulation Tournament 461. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 462 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 462. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 463 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 463. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 464 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 464. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 465 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 465. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 466 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 466. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 467 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 467. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 468 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 468. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 469 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# --- Finished Simulation Tournament 469. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 470 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 470. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 471 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 471. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 472 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing river...
# --- Finished Simulation Tournament 472. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 473 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 473. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 474 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing river...
# --- All-in Runout Detected ---
# --- Finished Simulation Tournament 474. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 475 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing river...
# --- Finished Simulation Tournament 475. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 476 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing river...
# --- Finished Simulation Tournament 476. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 477 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 477. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 478 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 478. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 479 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 479. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 480 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 480. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 481 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 481. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 482 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 482. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 483 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 483. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 484 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 484. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 485 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 485. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 486 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 486. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 487 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 487. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 488 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 488. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 489 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 489. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 490 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 490. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 491 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 491. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 492 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 492. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 493 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 493. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 494 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 494. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 495 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 495. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 496 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 496. Final Reward: 50000.00 ---
# --- Starting Simulation Tournament 497 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 497. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 498 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- All-in Runout Detected ---
# Dealing river...
# --- Finished Simulation Tournament 498. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 499 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 499. Final Reward: -10000.00 ---
# --- Starting Simulation Tournament 500 ---
#
# ===== RESETTING TOURNAMENT =====
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# --- Finished Simulation Tournament 500. Final Reward: -10000.00 ---
#   Completed Tournament 500/500...
#
# --- Simulation Complete ---
# Average Tournament Reward: 920.00
# Summary results appended to: simulation_results.csv
# Detailed logs written to: detailed_simulation_log.csv
# Closing Poker Environment.
# Simulation finished.

# %%
# !python main.py simulate --checkpoint "checkpoints/final_agent_model.pt" --episodes 100 --seat_config "agent,random,model,empty,random,model"

# %% [markdown]
# ### 3. Analyze Command
# **Purpose:** Analyze the detailed simulation log.

# %%
# !python main.py analyze --detailed_log Output_CSVs/detailed_simulation_log.csv
# Out:
# Starting analysis process...
# Ensured output directory exists: Output_CSVs
# Log loaded successfully from Output_CSVs/detailed_simulation_log.csv. Rows: 7362
# Analysis summary saved to Output_CSVs\decision_analysis_summary.csv
#
# --- Analysis Summary for Agent ID: 1 ---
#
# --- Action Summary (Preflop) ---
#    Action  Count  Avg_Reward
# bet_small   3601  105.246598
#      call   1125   55.200000
#    all_in    694  720.136167
#      fold    616 -619.875000
#   bet_big      4    0.000000
#     check      2    0.000000
#
# --- Starting Hand Distribution (Preflop) ---
# Hand_Class  Count
# Q5 Offsuit     83
# 63 Offsuit     79
# 97 Offsuit     77
# 92 Offsuit     76
# Q7 Offsuit     75
# Q4 Offsuit     73
# K7 Offsuit     70
# J3 Offsuit     68
# J7 Offsuit     67
# Q3 Offsuit     66
# AJ Offsuit     66
# 95 Offsuit     66
# 62 Offsuit     66
# K3 Offsuit     65
# T9 Offsuit     64
# KT Offsuit     64
# A6 Offsuit     63
# K8 Offsuit     62
# 93 Offsuit     62
# T3 Offsuit     62
# K2 Offsuit     61
# K6 Offsuit     61
# 72 Offsuit     61
# A4 Offsuit     61
# J6 Offsuit     60
# 42 Offsuit     60
# Q2 Offsuit     60
# T7 Offsuit     59
# 32 Offsuit     59
# 85 Offsuit     58
# KJ Offsuit     58
# QT Offsuit     57
# 54 Offsuit     57
# J5 Offsuit     57
# 86 Offsuit     57
# T5 Offsuit     56
# 82 Offsuit     56
# T2 Offsuit     56
# Q9 Offsuit     55
# A8 Offsuit     54
# J9 Offsuit     54
# 43 Offsuit     54
# K9 Offsuit     53
# 84 Offsuit     53
# AQ Offsuit     53
# 76 Offsuit     53
# Q6 Offsuit     53
# A3 Offsuit     52
# J2 Offsuit     52
# 53 Offsuit     52
# A2 Offsuit     51
# J8 Offsuit     51
# 96 Offsuit     50
# 74 Offsuit     50
# T6 Offsuit     50
# A9 Offsuit     49
# 52 Offsuit     48
# Q8 Offsuit     48
# K4 Offsuit     48
# 64 Offsuit     48
# 65 Offsuit     46
# 98 Offsuit     46
# AT Offsuit     45
# T8 Offsuit     45
# J4 Offsuit     44
# A5 Offsuit     44
# A7 Offsuit     44
# T4 Offsuit     44
# 83 Offsuit     43
# AK Offsuit     43
# QJ Offsuit     41
# K5 Offsuit     41
# JT Offsuit     41
# KQ Offsuit     39
# 73 Offsuit     39
#     Pair Q     38
# 87 Offsuit     37
#     Pair 8     36
#  Q5 Suited     36
# 75 Offsuit     35
#  Q7 Suited     32
#     Pair 9     32
#  J6 Suited     31
#  76 Suited     30
# 94 Offsuit     30
#  J3 Suited     30
#     Pair K     29
#     Pair 4     29
#     Pair 5     27
#  85 Suited     27
#  T4 Suited     27
#  92 Suited     26
#     Pair 7     26
#  KQ Suited     25
#  K2 Suited     25
#     Pair T     25
#  QJ Suited     24
#  JT Suited     24
#  62 Suited     24
#  86 Suited     24
#  KJ Suited     23
#  97 Suited     23
#  T7 Suited     23
#  43 Suited     23
#  J8 Suited     23
#  A4 Suited     23
#  A5 Suited     23
#     Pair 3     23
#  Q3 Suited     23
#     Pair A     22
#  QT Suited     22
#     Pair 2     21
#  AQ Suited     21
#  Q6 Suited     21
#  J2 Suited     21
#  74 Suited     20
#  64 Suited     20
#  AJ Suited     19
#     Pair J     19
#  K3 Suited     19
#  A9 Suited     19
#     Pair 6     19
#  T3 Suited     18
#  A6 Suited     18
#  73 Suited     18
#  Q8 Suited     18
#  K7 Suited     18
#  A3 Suited     18
#  32 Suited     17
#  52 Suited     17
#  K8 Suited     17
#  72 Suited     17
#  T8 Suited     17
#  94 Suited     17
#  K9 Suited     16
#  AK Suited     16
#  T5 Suited     16
#  AT Suited     16
#  J4 Suited     16
#  87 Suited     16
#  96 Suited     16
#  J5 Suited     16
#  54 Suited     15
#  75 Suited     15
#  J7 Suited     15
#  J9 Suited     14
#  63 Suited     14
#  93 Suited     14
#  T2 Suited     14
#  A8 Suited     13
#  A7 Suited     13
#  T6 Suited     13
#  Q9 Suited     13
#  Q2 Suited     12
#  84 Suited     12
#  83 Suited     12
#  Q4 Suited     11
#  53 Suited     11
#  K5 Suited     11
#  98 Suited     10
#  95 Suited     10
#  A2 Suited     10
#  T9 Suited      9
#  82 Suited      9
#  KT Suited      8
#  K6 Suited      7
#  K4 Suited      7
#  65 Suited      5
#  42 Suited      4
#
# --- Mean Hand Strength by Action Type ---
# Action_Type  Mean_Hand_Strength
#  Aggressive           19.551524
#     Passive           19.555364
#
# --- Correlation between Hand Strength and Reward ---
# 0.03
#
# Comparison to Best Poker Practices:
#  - Mean Hand Strength when playing Aggressively: 19.55
#  - Mean Hand Strength when playing Passively: 19.56
#    (Unexpected: aggressive actions do not have higher average strength.)
#  - Correlation between Hand Strength and Reward: 0.03
#    (Weak correlation suggests decisions may not strongly align with hand strength.)
#
# Standard preflop guidelines advise aggression with premium holdings. Use results for tuning.
#
# Saved action distribution plot to plots\action_distribution.png
# Saved hand distribution plot to plots\hand_distribution.png
# Saved strength by action plot to plots\strength_by_action.png
# Analysis finished.

# %% [markdown]
# ### 4. GUI Command
# **Purpose:** Launch the graphical user interface.

# %%
# !python main.py ui
# Out:
# Launching Enhanced Poker UI...
# Relative imports successful.
# Using device: cpu
# Setting up game...
# Using Seat Config: {0: 'player', 1: 'model', 2: 'model', 3: 'model', 4: 'model', 5: 'model'}
# Checkpoint Paths: {0: None, 1: None, 2: None, 3: None, 4: None, 5: None}
# Looking for checkpoints in: c:\Users\Matheus Viana\Documents\School\DS 440W\PokerBotRL\checkpoints
# Found default checkpoint: c:\Users\Matheus Viana\Documents\School\DS 440W\PokerBotRL\checkpoints\final_agent_model.pt
# Successfully loaded model from c:\Users\Matheus Viana\Documents\School\DS 440W\PokerBotRL\checkpoints\final_agent_model.pt onto cpu.
# Primary agent model loaded successfully.
# Poker Environment Initialized/Reset.
# Set Seat 2 policy to: model
# Set Seat 3 policy to: model
# Set Seat 4 policy to: model
# Set Seat 5 policy to: model
# Set Seat 6 policy to: model
# Clearing table state visuals...
# Animation speed set to: 1.0x
#
# --- Starting New Tournament ---
#
# ===== RESETTING TOURNAMENT =====
# Opponent 2 (model) turn. Scheduling action...
# Executing opponent turn...
# Human player's turn.
# Warning: Saved type 'agent' for seat 1 is invalid. Resetting to 'empty'.
# Player action chosen: fold (Index: 0)
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Round Ended ---
# Scheduling next round...
# Starting next round...
# Human player's turn.
# Warning: Saved type 'agent' for seat 1 is invalid. Resetting to 'empty'.
# Setting up game...
# Using Seat Config: {0: 'agent', 1: 'model', 2: 'model', 3: 'model', 4: 'model', 5: 'model'}
# Checkpoint Paths: {0: None, 1: None, 2: None, 3: None, 4: None, 5: None}
# Looking for checkpoints in: c:\Users\Matheus Viana\Documents\School\DS 440W\PokerBotRL\checkpoints
# Found default checkpoint: c:\Users\Matheus Viana\Documents\School\DS 440W\PokerBotRL\checkpoints\final_agent_model.pt
# Successfully loaded model from c:\Users\Matheus Viana\Documents\School\DS 440W\PokerBotRL\checkpoints\final_agent_model.pt onto cpu.
# Primary agent model loaded successfully.
# Closing Poker Environment.
# Previous environment closed.
# Poker Environment Initialized/Reset.
# Set Seat 2 policy to: model
# Set Seat 3 policy to: model
# Set Seat 4 policy to: model
# Set Seat 5 policy to: model
# Set Seat 6 policy to: model
# Clearing table state visuals...
#
# --- Starting New Tournament ---
#
# ===== RESETTING TOURNAMENT =====
# Opponent 5 (model) turn. Scheduling action...
# Executing opponent turn...
# Human player's turn.
# Player action chosen: all_in (Index: 5)
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Round Ended ---
# Scheduling next round...
# Starting next round...
# Human player's turn.
# Player action chosen: call (Index: 1)
# Human player's turn.
# Player action chosen: call (Index: 1)
# Human player's turn.
# Player action chosen: fold (Index: 0)
# --- Round Ended ---
# Scheduling next round...
# Starting next round...
# Human player's turn.
# Player action chosen: bet_big (Index: 4)
# Human player's turn.
# Player action chosen: call (Index: 1)
# Human player's turn.
# Player action chosen: call (Index: 1)
# Human player's turn.
# Player action chosen: call (Index: 1)
# Human player's turn.
# Player action chosen: call (Index: 1)
# Human player's turn.
# Player action chosen: check (Index: 2)
# Human player's turn.
# Player action chosen: check (Index: 2)
# Human player's turn.
# Warning: Saved type 'agent' for seat 1 is invalid. Resetting to 'empty'.
# Seat configuration updated: {0: 'player', 1: 'model', 2: 'model', 3: 'model', 4: 'model', 5: 'model'}
# Checkpoint paths updated: {0: None, 1: 'C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt', 2: 'C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt', 3: 'C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt', 4: 'C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt', 5: 'C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt'}
# Setting up game...
# Using Seat Config: {0: 'player', 1: 'model', 2: 'model', 3: 'model', 4: 'model', 5: 'model'}
# Checkpoint Paths: {0: None, 1: 'C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt', 2: 'C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt', 3: 'C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt', 4: 'C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt', 5: 'C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt'}
# Looking for checkpoints in: c:\Users\Matheus Viana\Documents\School\DS 440W\PokerBotRL\checkpoints
# Found default checkpoint: c:\Users\Matheus Viana\Documents\School\DS 440W\PokerBotRL\checkpoints\final_agent_model.pt
# Successfully loaded model from c:\Users\Matheus Viana\Documents\School\DS 440W\PokerBotRL\checkpoints\final_agent_model.pt onto cpu.
# Primary agent model loaded successfully.
# Loading specific model for Seat 2 from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt
# Successfully loaded model from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt onto cpu.
# Successfully loaded specific model for Seat 2.
# Loading specific model for Seat 3 from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt
# Successfully loaded model from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt onto cpu.
# Successfully loaded specific model for Seat 3.
# Loading specific model for Seat 4 from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt
# Successfully loaded model from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt onto cpu.
# Successfully loaded specific model for Seat 4.
# Loading specific model for Seat 5 from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt
# Successfully loaded model from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt onto cpu.
# Successfully loaded specific model for Seat 5.
# Loading specific model for Seat 6 from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt
# Successfully loaded model from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt onto cpu.
# Successfully loaded specific model for Seat 6.
# Closing Poker Environment.
# Previous environment closed.
# Poker Environment Initialized/Reset.
# Set Seat 2 policy to: model
# Set Seat 3 policy to: model
# Set Seat 4 policy to: model
# Set Seat 5 policy to: model
# Set Seat 6 policy to: model
# Clearing table state visuals...
#
# --- Starting New Tournament ---
#
# ===== RESETTING TOURNAMENT =====
# Opponent 5 (model) turn. Scheduling action...
# Executing opponent turn...
# Human player's turn.
# Player action chosen: call (Index: 1)
# Human player's turn.
# Player action chosen: fold (Index: 0)
# --- Round Ended ---
# Scheduling next round...
# Starting next round...
# Human player's turn.
# Player action chosen: call (Index: 1)
# Human player's turn.
# Player action chosen: all_in (Index: 5)
# Opponent 2 (model) turn. Scheduling action...
# Executing opponent turn...
# --- All-in Runout Detected ---
# Dealing turn...
# Dealing river...
# ===== Tournament Ended =====
# Setting up game...
# Using Seat Config: {0: 'agent', 1: 'model', 2: 'model', 3: 'model', 4: 'model', 5: 'model'}
# Checkpoint Paths: {0: None, 1: 'C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt', 2: 'C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt', 3: 'C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt', 4: 'C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt', 5: 'C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt'}
# Looking for checkpoints in: c:\Users\Matheus Viana\Documents\School\DS 440W\PokerBotRL\checkpoints
# Found default checkpoint: c:\Users\Matheus Viana\Documents\School\DS 440W\PokerBotRL\checkpoints\final_agent_model.pt
# Successfully loaded model from c:\Users\Matheus Viana\Documents\School\DS 440W\PokerBotRL\checkpoints\final_agent_model.pt onto cpu.
# Primary agent model loaded successfully.
# Loading specific model for Seat 2 from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt
# Successfully loaded model from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt onto cpu.
# Successfully loaded specific model for Seat 2.
# Loading specific model for Seat 3 from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt
# Successfully loaded model from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt onto cpu.
# Successfully loaded specific model for Seat 3.
# Loading specific model for Seat 4 from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt
# Successfully loaded model from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt onto cpu.
# Successfully loaded specific model for Seat 4.
# Loading specific model for Seat 5 from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt
# Successfully loaded model from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt onto cpu.
# Successfully loaded specific model for Seat 5.
# Loading specific model for Seat 6 from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt
# Successfully loaded model from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt onto cpu.
# Successfully loaded specific model for Seat 6.
# Closing Poker Environment.
# Previous environment closed.
# Poker Environment Initialized/Reset.
# Set Seat 2 policy to: model
# Set Seat 3 policy to: model
# Set Seat 4 policy to: model
# Set Seat 5 policy to: model
# Set Seat 6 policy to: model
# Clearing table state visuals...
#
# --- Starting New Tournament ---
#
# ===== RESETTING TOURNAMENT =====
# Opponent 4 (model) turn. Scheduling action...
# Executing opponent turn...
# Human player's turn.
# Player action chosen: fold (Index: 0)
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# --- Round Ended ---
# Scheduling next round...
# Starting next round...
# Human player's turn.
# Player action chosen: call (Index: 1)
# Human player's turn.
# Player action chosen: call (Index: 1)
# Human player's turn.
# Player action chosen: call (Index: 1)
# Human player's turn.
# Player action chosen: all_in (Index: 5)
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# ===== Tournament Ended =====
# Setting up game...
# Using Seat Config: {0: 'agent', 1: 'model', 2: 'model', 3: 'model', 4: 'model', 5: 'model'}
# Checkpoint Paths: {0: None, 1: 'C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt', 2: 'C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt', 3: 'C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt', 4: 'C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt', 5: 'C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt'}
# Looking for checkpoints in: c:\Users\Matheus Viana\Documents\School\DS 440W\PokerBotRL\checkpoints
# Found default checkpoint: c:\Users\Matheus Viana\Documents\School\DS 440W\PokerBotRL\checkpoints\final_agent_model.pt
# Successfully loaded model from c:\Users\Matheus Viana\Documents\School\DS 440W\PokerBotRL\checkpoints\final_agent_model.pt onto cpu.
# Primary agent model loaded successfully.
# Loading specific model for Seat 2 from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt
# Successfully loaded model from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt onto cpu.
# Successfully loaded specific model for Seat 2.
# Loading specific model for Seat 3 from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt
# Successfully loaded model from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt onto cpu.
# Successfully loaded specific model for Seat 3.
# Loading specific model for Seat 4 from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt
# Successfully loaded model from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt onto cpu.
# Successfully loaded specific model for Seat 4.
# Loading specific model for Seat 5 from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt
# Successfully loaded model from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt onto cpu.
# Successfully loaded specific model for Seat 5.
# Loading specific model for Seat 6 from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt
# Successfully loaded model from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt onto cpu.
# Successfully loaded specific model for Seat 6.
# Closing Poker Environment.
# Previous environment closed.
# Poker Environment Initialized/Reset.
# Set Seat 2 policy to: model
# Set Seat 3 policy to: model
# Set Seat 4 policy to: model
# Set Seat 5 policy to: model
# Set Seat 6 policy to: model
# Clearing table state visuals...
#
# --- Starting New Tournament ---
#
# ===== RESETTING TOURNAMENT =====
# Opponent 3 (model) turn. Scheduling action...
# Executing opponent turn...
# Human player's turn.
# Player action chosen: all_in (Index: 5)
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# ===== Tournament Ended =====
# Setting up game...
# Using Seat Config: {0: 'agent', 1: 'model', 2: 'model', 3: 'model', 4: 'model', 5: 'model'}
# Checkpoint Paths: {0: None, 1: 'C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt', 2: 'C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt', 3: 'C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt', 4: 'C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt', 5: 'C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt'}
# Looking for checkpoints in: c:\Users\Matheus Viana\Documents\School\DS 440W\PokerBotRL\checkpoints
# Found default checkpoint: c:\Users\Matheus Viana\Documents\School\DS 440W\PokerBotRL\checkpoints\final_agent_model.pt
# Successfully loaded model from c:\Users\Matheus Viana\Documents\School\DS 440W\PokerBotRL\checkpoints\final_agent_model.pt onto cpu.
# Primary agent model loaded successfully.
# Loading specific model for Seat 2 from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt
# Successfully loaded model from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt onto cpu.
# Successfully loaded specific model for Seat 2.
# Loading specific model for Seat 3 from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt
# Successfully loaded model from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt onto cpu.
# Successfully loaded specific model for Seat 3.
# Loading specific model for Seat 4 from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt
# Successfully loaded model from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt onto cpu.
# Successfully loaded specific model for Seat 4.
# Loading specific model for Seat 5 from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt
# Successfully loaded model from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt onto cpu.
# Successfully loaded specific model for Seat 5.
# Loading specific model for Seat 6 from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt
# Successfully loaded model from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt onto cpu.
# Successfully loaded specific model for Seat 6.
# Closing Poker Environment.
# Previous environment closed.
# Poker Environment Initialized/Reset.
# Set Seat 2 policy to: model
# Set Seat 3 policy to: model
# Set Seat 4 policy to: model
# Set Seat 5 policy to: model
# Set Seat 6 policy to: model
# Clearing table state visuals...
#
# --- Starting New Tournament ---
#
# ===== RESETTING TOURNAMENT =====
# Opponent 3 (model) turn. Scheduling action...
# Executing opponent turn...
# Human player's turn.
# Player action chosen: all_in (Index: 5)
# --- All-in Runout Detected ---
# Dealing flop...
# Dealing turn...
# Dealing river...
# ===== Tournament Ended =====
# Setting up game...
# Using Seat Config: {0: 'agent', 1: 'model', 2: 'model', 3: 'model', 4: 'model', 5: 'model'}
# Checkpoint Paths: {0: None, 1: 'C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt', 2: 'C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt', 3: 'C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt', 4: 'C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt', 5: 'C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt'}
# Looking for checkpoints in: c:\Users\Matheus Viana\Documents\School\DS 440W\PokerBotRL\checkpoints
# Found default checkpoint: c:\Users\Matheus Viana\Documents\School\DS 440W\PokerBotRL\checkpoints\final_agent_model.pt
# Successfully loaded model from c:\Users\Matheus Viana\Documents\School\DS 440W\PokerBotRL\checkpoints\final_agent_model.pt onto cpu.
# Primary agent model loaded successfully.
# Loading specific model for Seat 2 from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt
# Successfully loaded model from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt onto cpu.
# Successfully loaded specific model for Seat 2.
# Loading specific model for Seat 3 from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt
# Successfully loaded model from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt onto cpu.
# Successfully loaded specific model for Seat 3.
# Loading specific model for Seat 4 from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt
# Successfully loaded model from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt onto cpu.
# Successfully loaded specific model for Seat 4.
# Loading specific model for Seat 5 from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt
# Successfully loaded model from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt onto cpu.
# Successfully loaded specific model for Seat 5.
# Loading specific model for Seat 6 from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt
# Successfully loaded model from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt onto cpu.
# Successfully loaded specific model for Seat 6.
# Closing Poker Environment.
# Previous environment closed.
# Poker Environment Initialized/Reset.
# Set Seat 2 policy to: model
# Set Seat 3 policy to: model
# Set Seat 4 policy to: model
# Set Seat 5 policy to: model
# Set Seat 6 policy to: model
# Clearing table state visuals...
#
# --- Starting New Tournament ---
#
# ===== RESETTING TOURNAMENT =====
# Opponent 3 (model) turn. Scheduling action...
# Executing opponent turn...
# Human player's turn.
# Player action chosen: fold (Index: 0)
# --- Round Ended ---
# Scheduling next round...
# Starting next round...
# Human player's turn.
# Player action chosen: fold (Index: 0)
# Opponent 3 (model) turn. Scheduling action...
# Executing opponent turn...
# --- Round Ended ---
# Scheduling next round...
# Starting next round...
# Human player's turn.
# Player action chosen: call (Index: 1)
# Human player's turn.
# Player action chosen: bet_big (Index: 4)
# Opponent 3 (model) turn. Scheduling action...
# Executing opponent turn...
# Opponent 3 (model) turn. Scheduling action...
# Executing opponent turn...
# --- All-in Runout Detected ---
# Dealing river...
# --- Round Ended ---
# Scheduling next round...
# Starting next round...
# Human player's turn.
# Warning: Saved type 'agent' for seat 1 is invalid. Resetting to 'empty'.
# Warning: Saved type 'agent' for seat 1 is invalid. Resetting to 'empty'.
# Seat configuration updated: {0: 'player', 1: 'random', 2: 'random', 3: 'random', 4: 'random', 5: 'random'}
# Checkpoint paths updated: {0: None, 1: None, 2: None, 3: None, 4: None, 5: None}
# Setting up game...
# Using Seat Config: {0: 'player', 1: 'random', 2: 'random', 3: 'random', 4: 'random', 5: 'random'}
# Checkpoint Paths: {0: None, 1: None, 2: None, 3: None, 4: None, 5: None}
# Looking for checkpoints in: c:\Users\Matheus Viana\Documents\School\DS 440W\PokerBotRL\checkpoints
# Found default checkpoint: c:\Users\Matheus Viana\Documents\School\DS 440W\PokerBotRL\checkpoints\final_agent_model.pt
# Successfully loaded model from c:\Users\Matheus Viana\Documents\School\DS 440W\PokerBotRL\checkpoints\final_agent_model.pt onto cpu.
# Primary agent model loaded successfully.
# Closing Poker Environment.
# Previous environment closed.
# Poker Environment Initialized/Reset.
# Set Seat 2 policy to: random
# Set Seat 3 policy to: random
# Set Seat 4 policy to: random
# Set Seat 5 policy to: random
# Set Seat 6 policy to: random
# Clearing table state visuals...
#
# --- Starting New Tournament ---
#
# ===== RESETTING TOURNAMENT =====
# Opponent 3 (random) turn. Scheduling action...
# Executing opponent turn...
# Human player's turn.
# Warning: Saved type 'agent' for seat 1 is invalid. Resetting to 'empty'.
# Seat configuration updated: {0: 'player', 1: 'model', 2: 'empty', 3: 'empty', 4: 'empty', 5: 'empty'}
# Checkpoint paths updated: {0: None, 1: 'C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt', 2: None, 3: None, 4: None, 5: None}
# Setting up game...
# Using Seat Config: {0: 'player', 1: 'model', 2: 'empty', 3: 'empty', 4: 'empty', 5: 'empty'}
# Checkpoint Paths: {0: None, 1: 'C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt', 2: None, 3: None, 4: None, 5: None}
# Looking for checkpoints in: c:\Users\Matheus Viana\Documents\School\DS 440W\PokerBotRL\checkpoints
# Found default checkpoint: c:\Users\Matheus Viana\Documents\School\DS 440W\PokerBotRL\checkpoints\final_agent_model.pt
# Successfully loaded model from c:\Users\Matheus Viana\Documents\School\DS 440W\PokerBotRL\checkpoints\final_agent_model.pt onto cpu.
# Primary agent model loaded successfully.
# Loading specific model for Seat 2 from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt
# Successfully loaded model from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt onto cpu.
# Successfully loaded specific model for Seat 2.
# Closing Poker Environment.
# Previous environment closed.
# Poker Environment Initialized/Reset.
# Set Seat 2 policy to: model
# Clearing table state visuals...
#
# --- Starting New Tournament ---
#
# ===== RESETTING TOURNAMENT =====
# Human player's turn.
# Player action chosen: all_in (Index: 5)
# --- Round Ended ---
# Scheduling next round...
# Starting next round...
# Human player's turn.
# Setting up game...
# Using Seat Config: {0: 'agent', 1: 'model', 2: 'empty', 3: 'empty', 4: 'empty', 5: 'empty'}
# Checkpoint Paths: {0: None, 1: 'C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt', 2: None, 3: None, 4: None, 5: None}
# Looking for checkpoints in: c:\Users\Matheus Viana\Documents\School\DS 440W\PokerBotRL\checkpoints
# Found default checkpoint: c:\Users\Matheus Viana\Documents\School\DS 440W\PokerBotRL\checkpoints\final_agent_model.pt
# Successfully loaded model from c:\Users\Matheus Viana\Documents\School\DS 440W\PokerBotRL\checkpoints\final_agent_model.pt onto cpu.
# Primary agent model loaded successfully.
# Loading specific model for Seat 2 from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt
# Successfully loaded model from C:/Users/Matheus Viana/Documents/School/DS 440W/PokerBotRL/checkpoints/checkpoint_31200.pt onto cpu.
# Successfully loaded specific model for Seat 2.
# Closing Poker Environment.
# Previous environment closed.
# Poker Environment Initialized/Reset.
# Set Seat 2 policy to: model
# Clearing table state visuals...
#
# --- Starting New Tournament ---
#
# ===== RESETTING TOURNAMENT =====
# Human player's turn.
# Warning: Saved type 'agent' for seat 1 is invalid. Resetting to 'empty'.
# Player action chosen: all_in (Index: 5)
# --- Round Ended ---
# Scheduling next round...
# Starting next round...
# Human player's turn.
# Player action chosen: call (Index: 1)
# Human player's turn.
# Player action chosen: bet_small (Index: 3)
# Human player's turn.
# Player action chosen: call (Index: 1)
# Human player's turn.
# Player action chosen: check (Index: 2)
# Human player's turn.
# Player action chosen: call (Index: 1)
# Human player's turn.
# Player action chosen: bet_small (Index: 3)
# Human player's turn.
# Player action chosen: call (Index: 1)
# --- Round Ended ---
# Scheduling next round...
# Starting next round...
# Human player's turn.
# UI closed.

# %%
# !taskkill /F /IM python.exe
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
